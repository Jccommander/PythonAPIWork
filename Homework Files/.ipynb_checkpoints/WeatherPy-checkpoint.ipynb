# %% [markdown]
#    Observable trends based upon the plots generated below:
#    We can see that, according to the temperature plot, temperature is at its highest the closer one is to the equator, with temperatures falling off both higher and lower than the equator latitudinally. This follows conventional logic, but it can be seen here, along with the fact that 20 degrees above the equator one sees a series of spikes in temperature, which can be attributed to the time of year, as it is summer in the upper hemisphere.
#    The second distinct trend that can be taken from these graphs is that cloudiness and wind speed of no observable correlation with latitude. The cloudiness graph is scattered near evenly across its entire surface, indicating a nearly random spread, meaning that latitude has no effect on cloudiness. Wind speed, meanwhile, tends towards the lower side of the graph, though a few higher values are recorded they do not favor any particular trend on latitude. We can therefore conclude that wind speed and cloudiness are not influenced by latitude.
#    Lastly, our third observable trend is that humidity has a very soft trend, with cities closer to the equator slightly more likely to be humid. The middle cluster near latitude degree 0 has far less cities with low humidity compared to the edges of the graph, though this trend is definitely not as strong as temperature was. One would most likely need to repeat this data collection process several times before they could confidently conclude latitude has an effect on humidity, but this graph at least points to the possibility of latitude having a significant impact on humidity.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from matplotlib import style
from datetime import datetime
import pandas as pd
import numpy as np
import requests
import time
import json
style.use('ggplot')

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_key

weather_data = []
counter = 1

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

print("Beginning Data Retrieval")
print("------------------------------")

for city in cities:

    # Build query URL
    query_url = url + "&q=" + city
    
    # Request json file and decrypt it, using a Try / Except Block to avoid errors
    
    try:
        request = requests.get(query_url).json()
    
    # Store information from the city's json into the weather data list
    
        weather_data.append({"City":request['name'],\
                             "Country":request['sys']['country'],\
                             "Max Temp":request['main']['temp_max'],\
                             "Humidity":request['main']['humidity'],\
                             "Clouds":request['clouds']['all'],\
                             "Lat":request['coord']['lat'],\
                             "Lon":request['coord']['lon'],\
                             "Wind Speed":request['wind']['speed'],})
    
    # Print success message, with the number of the current city and its name
        print(f"Successfully stored information for City #{counter}: {city}")
        print(query_url)
    
    # Finish exception with an error message
    except Exception:
        print(f"Unfortunately, there was an error for City #{counter}: {city}")
        print(query_url)
        
    # Update counter, and then have the loop wait a second, so as to slow down the number of requests to the API
    
    counter += 1
    
    time.sleep(1)

print("------------------------------")
print("Data Retrieval Completed")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Successfully stored information for City #1: quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=quatre cocos
# Successfully stored information for City #2: rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=rikitea
# Successfully stored information for City #3: kingston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kingston
# Successfully stored information for City #4: upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=upernavik
# Successfully stored information for City #5: visp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=visp
# Successfully stored information for City #6: diapaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=diapaga
# Successfully stored information for City #7: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=guerrero negro
# Successfully stored information for City #8: safford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=safford
# Successfully stored information for City #9: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bambous virieux
# Successfully stored information for City #10: aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=aswan
# Successfully stored information for City #11: cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cape town
# Successfully stored information for City #12: tres arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tres arroyos
# Successfully stored information for City #13: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tasiilaq
# Successfully stored information for City #14: alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=alofi
# Successfully stored information for City #15: vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=vaini
# Successfully stored information for City #16: ariquemes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ariquemes
# Unfortunately, there was an error for City #17: belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=belushya guba
# Successfully stored information for City #18: punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=punta arenas
# Successfully stored information for City #19: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=leningradskiy
# Successfully stored information for City #20: taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=taltal
# Successfully stored information for City #21: podolinec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=podolinec
# Successfully stored information for City #22: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=qaanaaq
# Successfully stored information for City #23: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=saint-philippe
# Successfully stored information for City #24: port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=port alfred
# Successfully stored information for City #25: jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=jamestown
# Successfully stored information for City #26: mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mar del plata
# Successfully stored information for City #27: emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=emba
# Successfully stored information for City #28: mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mataura
# Successfully stored information for City #29: tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tual
# Successfully stored information for City #30: hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hamilton
# Successfully stored information for City #31: melfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=melfi
# Successfully stored information for City #32: broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=broome
# Successfully stored information for City #33: provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=provideniya
# Successfully stored information for City #34: taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=taoudenni
# Successfully stored information for City #35: waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=waingapu
# Successfully stored information for City #36: barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=barrow
# Successfully stored information for City #37: kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kropotkin
# Successfully stored information for City #38: kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kodiak
# Successfully stored information for City #39: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=nikolskoye
# Successfully stored information for City #40: kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kapaa
# Successfully stored information for City #41: kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kavaratti
# Successfully stored information for City #42: lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lebu
# Successfully stored information for City #43: airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=airai
# Successfully stored information for City #44: henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=henties bay
# Successfully stored information for City #45: avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=avera
# Successfully stored information for City #46: martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=martapura
# Successfully stored information for City #47: butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=butaritari
# Successfully stored information for City #48: qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=qaqortoq
# Successfully stored information for City #49: hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hermanus
# Successfully stored information for City #50: busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=busselton
# Successfully stored information for City #51: cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cabo san lucas
# Successfully stored information for City #52: ibra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ibra
# Successfully stored information for City #53: ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ponta delgada
# Successfully stored information for City #54: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tuktoyaktuk
# Successfully stored information for City #55: moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=moose factory
# Unfortunately, there was an error for City #56: barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=barentsburg
# Successfully stored information for City #57: buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=buraydah
# Successfully stored information for City #58: loa janan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=loa janan
# Successfully stored information for City #59: la palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=la palma
# Successfully stored information for City #60: santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=santa maria
# Successfully stored information for City #61: ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ushuaia
# Successfully stored information for City #62: hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hilo
# Successfully stored information for City #63: kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kaitangata
# Successfully stored information for City #64: san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=san patricio
# Unfortunately, there was an error for City #65: tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tsihombe
# Successfully stored information for City #66: albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=albany
# Successfully stored information for City #67: marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=marawi
# Successfully stored information for City #68: dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=dikson
# Successfully stored information for City #69: sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sao joao da barra
# Successfully stored information for City #70: ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ngunguru
# Successfully stored information for City #71: castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=castro
# Unfortunately, there was an error for City #72: mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mys shmidta
# Successfully stored information for City #73: vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=vila velha
# Successfully stored information for City #74: marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=marystown
# Successfully stored information for City #75: tinskoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tinskoy
# Successfully stored information for City #76: carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=carutapera
# Successfully stored information for City #77: juba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=juba
# Successfully stored information for City #78: mataram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mataram
# Unfortunately, there was an error for City #79: bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bengkulu
# Successfully stored information for City #80: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=puerto ayora
# Successfully stored information for City #81: tatvan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tatvan
# Successfully stored information for City #82: seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=seoul
# Successfully stored information for City #83: hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hobart
# Unfortunately, there was an error for City #84: ijaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ijaki
# Unfortunately, there was an error for City #85: saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=saleaula
# Successfully stored information for City #86: lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lagoa
# Successfully stored information for City #87: kudat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kudat
# Successfully stored information for City #88: chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=chuy
# Successfully stored information for City #89: turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=turukhansk
# Successfully stored information for City #90: aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=aykhal
# Unfortunately, there was an error for City #91: artyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=artyk
# Successfully stored information for City #92: birecik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=birecik
# Successfully stored information for City #93: mykhaylivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mykhaylivka
# Successfully stored information for City #94: bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bluff
# Successfully stored information for City #95: moroni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=moroni
# Successfully stored information for City #96: ruidoso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ruidoso
# Successfully stored information for City #97: farah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=farah
# Successfully stored information for City #98: yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=yulara
# Successfully stored information for City #99: neftcala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=neftcala
# Unfortunately, there was an error for City #100: tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tabiauea
# Unfortunately, there was an error for City #101: haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=haibowan
# Successfully stored information for City #102: alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=alta floresta
# Successfully stored information for City #103: belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=belaya gora
# Successfully stored information for City #104: kabare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kabare
# Successfully stored information for City #105: polonnaruwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=polonnaruwa
# Successfully stored information for City #106: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hithadhoo
# Successfully stored information for City #107: hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hammerfest
# Successfully stored information for City #108: damoh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=damoh
# Unfortunately, there was an error for City #109: taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=taolanaro
# Successfully stored information for City #110: kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kalianget
# Successfully stored information for City #111: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bredasdorp
# Successfully stored information for City #112: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ribeira grande
# Successfully stored information for City #113: new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=new norfolk
# Successfully stored information for City #114: luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=luderitz
# Unfortunately, there was an error for City #115: krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=krasnoselkup
# Successfully stored information for City #116: malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=malanje
# Successfully stored information for City #117: ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ayan
# Successfully stored information for City #118: nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=nanortalik
# Successfully stored information for City #119: ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ostrovnoy
# Successfully stored information for City #120: karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=karratha
# Successfully stored information for City #121: iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=iqaluit
# Successfully stored information for City #122: talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=talara
# Successfully stored information for City #123: tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tiksi
# Unfortunately, there was an error for City #124: el badari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=el badari
# Successfully stored information for City #125: avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=avarua
# Successfully stored information for City #126: lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lorengau
# Successfully stored information for City #127: constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=constitucion
# Unfortunately, there was an error for City #128: bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bac lieu
# Successfully stored information for City #129: torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=torbay
# Successfully stored information for City #130: cooma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cooma
# Successfully stored information for City #131: anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=anadyr
# Unfortunately, there was an error for City #132: korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=korla
# Successfully stored information for City #133: mont-de-marsan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mont-de-marsan
# Successfully stored information for City #134: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=port elizabeth
# Unfortunately, there was an error for City #135: falealupo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=falealupo
# Successfully stored information for City #136: havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=havre-saint-pierre
# Unfortunately, there was an error for City #137: acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=acarau
# Successfully stored information for City #138: jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=jalu
# Successfully stored information for City #139: panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=panaba
# Unfortunately, there was an error for City #140: nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=nguiu
# Successfully stored information for City #141: leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=leshukonskoye
# Unfortunately, there was an error for City #142: umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=umzimvubu
# Successfully stored information for City #143: belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=belyy yar
# Successfully stored information for City #144: bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bandarbeyla
# Successfully stored information for City #145: santa fe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=santa fe
# Successfully stored information for City #146: noshiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=noshiro
# Unfortunately, there was an error for City #147: solsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=solsvik
# Unfortunately, there was an error for City #148: vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=vaitupu
# Successfully stored information for City #149: luangwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=luangwa
# Successfully stored information for City #150: vilcun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=vilcun
# Successfully stored information for City #151: dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=dalvik
# Successfully stored information for City #152: yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=yellowknife
# Successfully stored information for City #153: kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kieta
# Successfully stored information for City #154: pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=pevek
# Successfully stored information for City #155: pallasovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=pallasovka
# Successfully stored information for City #156: damavand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=damavand
# Successfully stored information for City #157: kabwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kabwe
# Successfully stored information for City #158: puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=puerto del rosario
# Successfully stored information for City #159: kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kununurra
# Successfully stored information for City #160: codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=codrington
# Successfully stored information for City #161: berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=berlevag
# Successfully stored information for City #162: balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=balkanabat
# Successfully stored information for City #163: carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=carnarvon
# Successfully stored information for City #164: palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=palmer
# Successfully stored information for City #165: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=chokurdakh
# Successfully stored information for City #166: norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=norman wells
# Unfortunately, there was an error for City #167: lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lolua
# Successfully stored information for City #168: tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tocopilla
# Successfully stored information for City #169: nanyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=nanyang
# Successfully stored information for City #170: tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tecoanapa
# Successfully stored information for City #171: xacmaz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=xacmaz
# Successfully stored information for City #172: quesnel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=quesnel
# Unfortunately, there was an error for City #173: balimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=balimo
# Successfully stored information for City #174: tunceli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tunceli
# Successfully stored information for City #175: finnsnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=finnsnes
# Successfully stored information for City #176: half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=half moon bay
# Successfully stored information for City #177: trelew
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=trelew
# Successfully stored information for City #178: san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=san quintin
# Successfully stored information for City #179: gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=gigmoto
# Successfully stored information for City #180: khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=khatanga
# Successfully stored information for City #181: verdikoussa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=verdikoussa
# Successfully stored information for City #182: dakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=dakar
# Successfully stored information for City #183: east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=east london
# Successfully stored information for City #184: saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=saint-pierre
# Successfully stored information for City #185: dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=dingle
# Successfully stored information for City #186: harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=harper
# Successfully stored information for City #187: srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=srednekolymsk
# Successfully stored information for City #188: mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mugur-aksy
# Unfortunately, there was an error for City #189: rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=rungata
# Unfortunately, there was an error for City #190: karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=karaul
# Successfully stored information for City #191: mancora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mancora
# Unfortunately, there was an error for City #192: meilu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=meilu
# Successfully stored information for City #193: georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=georgetown
# Successfully stored information for City #194: escanaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=escanaba
# Successfully stored information for City #195: andilamena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=andilamena
# Successfully stored information for City #196: montepuez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=montepuez
# Successfully stored information for City #197: hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hasaki
# Successfully stored information for City #198: bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bilibino
# Successfully stored information for City #199: ler
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ler
# Successfully stored information for City #200: vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=vestmannaeyjar
# Unfortunately, there was an error for City #201: illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=illoqqortoormiut
# Successfully stored information for City #202: byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=byron bay
# Successfully stored information for City #203: morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=morondava
# Successfully stored information for City #204: labytnangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=labytnangi
# Successfully stored information for City #205: faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=faanui
# Successfully stored information for City #206: novokayakent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=novokayakent
# Successfully stored information for City #207: sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sitka
# Successfully stored information for City #208: virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=virginia beach
# Successfully stored information for City #209: husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=husavik
# Successfully stored information for City #210: goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=goderich
# Successfully stored information for City #211: knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=knysna
# Successfully stored information for City #212: abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=abha
# Successfully stored information for City #213: mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mahon
# Successfully stored information for City #214: zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=zhigansk
# Successfully stored information for City #215: tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tura
# Successfully stored information for City #216: bestobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bestobe
# Successfully stored information for City #217: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ponta do sol
# Successfully stored information for City #218: manaure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=manaure
# Successfully stored information for City #219: san ramon de la nueva oran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=san ramon de la nueva oran
# Successfully stored information for City #220: opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=opuwo
# Successfully stored information for City #221: mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mount isa
# Successfully stored information for City #222: hopkinsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hopkinsville
# Successfully stored information for City #223: thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=thompson
# Successfully stored information for City #224: moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=moree
# Unfortunately, there was an error for City #225: amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=amderma
# Successfully stored information for City #226: bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bethel
# Successfully stored information for City #227: santa isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=santa isabel
# Successfully stored information for City #228: omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=omsukchan
# Successfully stored information for City #229: mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mahebourg
# Successfully stored information for City #230: sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sept-iles
# Successfully stored information for City #231: atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=atuona
# Successfully stored information for City #232: gumdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=gumdag
# Successfully stored information for City #233: mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mitsamiouli
# Successfully stored information for City #234: russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=russell
# Successfully stored information for City #235: praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=praia da vitoria
# Successfully stored information for City #236: osmena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=osmena
# Successfully stored information for City #237: nortelandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=nortelandia
# Successfully stored information for City #238: omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=omboue
# Successfully stored information for City #239: boda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=boda
# Successfully stored information for City #240: davenda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=davenda
# Successfully stored information for City #241: flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=flinders
# Successfully stored information for City #242: saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=saldanha
# Successfully stored information for City #243: itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=itoman
# Successfully stored information for City #244: bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bathsheba
# Successfully stored information for City #245: paranaiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=paranaiba
# Successfully stored information for City #246: kishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kishi
# Successfully stored information for City #247: san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=san cristobal
# Successfully stored information for City #248: caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=caravelas
# Successfully stored information for City #249: acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=acajutla
# Successfully stored information for City #250: celinac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=celinac
# Successfully stored information for City #251: uarini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=uarini
# Successfully stored information for City #252: hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hualmay
# Successfully stored information for City #253: okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=okhotsk
# Successfully stored information for City #254: kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kavieng
# Successfully stored information for City #255: cantaura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cantaura
# Successfully stored information for City #256: tall kayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tall kayf
# Successfully stored information for City #257: kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kodinsk
# Successfully stored information for City #258: prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=prince rupert
# Unfortunately, there was an error for City #259: sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sakakah
# Successfully stored information for City #260: murray bridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=murray bridge
# Successfully stored information for City #261: mariental
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mariental
# Successfully stored information for City #262: colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=colares
# Successfully stored information for City #263: la gomera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=la gomera
# Unfortunately, there was an error for City #264: sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sentyabrskiy
# Successfully stored information for City #265: labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=labuhan
# Successfully stored information for City #266: xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=xai-xai
# Successfully stored information for City #267: bria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bria
# Successfully stored information for City #268: tecpan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tecpan
# Unfortunately, there was an error for City #269: sataua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sataua
# Successfully stored information for City #270: griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=griffith
# Successfully stored information for City #271: seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=seymchan
# Successfully stored information for City #272: samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=samarai
# Successfully stored information for City #273: benidorm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=benidorm
# Successfully stored information for City #274: qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=qasigiannguit
# Successfully stored information for City #275: victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=victoria
# Successfully stored information for City #276: bien hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bien hoa
# Successfully stored information for City #277: kumano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kumano
# Successfully stored information for City #278: taganak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=taganak
# Successfully stored information for City #279: vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=vila franca do campo
# Successfully stored information for City #280: rantauprapat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=rantauprapat
# Successfully stored information for City #281: san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=san juan
# Successfully stored information for City #282: saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=saskylakh
# Successfully stored information for City #283: hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hambantota
# Successfully stored information for City #284: klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=klaksvik
# Successfully stored information for City #285: atasu
# ...
# Successfully stored information for City #531: siderno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=siderno
# Successfully stored information for City #532: kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kamenka
# Successfully stored information for City #533: makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=makakilo city
# Unfortunately, there was an error for City #534: we
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=we
# Successfully stored information for City #535: rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=rawson
# Successfully stored information for City #536: lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lima
# Successfully stored information for City #537: rivera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=rivera
# Successfully stored information for City #538: ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=ilulissat
# Successfully stored information for City #539: broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=broken hill
# Successfully stored information for City #540: sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sola
# Successfully stored information for City #541: isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=isangel
# Successfully stored information for City #542: lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lazaro cardenas
# Successfully stored information for City #543: salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=salinopolis
# Successfully stored information for City #544: mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mogadishu
# Unfortunately, there was an error for City #545: morvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=morvi
# Successfully stored information for City #546: muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=muisne
# Successfully stored information for City #547: tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tezu
# Successfully stored information for City #548: comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=comodoro rivadavia
# Successfully stored information for City #549: pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=pundaguitan
# Successfully stored information for City #550: cacequi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cacequi
# Successfully stored information for City #551: normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=normandin
# Successfully stored information for City #552: westerland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=westerland
# Successfully stored information for City #553: fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=fort nelson
# Successfully stored information for City #554: paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=paita
# Successfully stored information for City #555: talas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=talas
# Successfully stored information for City #556: carbonia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=carbonia
# Successfully stored information for City #557: cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cherskiy
# Successfully stored information for City #558: bandiagara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bandiagara
# Successfully stored information for City #559: fenelon falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=fenelon falls
# Successfully stored information for City #560: sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sawakin
# Unfortunately, there was an error for City #561: wulanhaote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=wulanhaote
# Successfully stored information for City #562: esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=esperance
# Successfully stored information for City #563: manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=manokwari
# Successfully stored information for City #564: teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=teguise
# Unfortunately, there was an error for City #565: urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=urumqi
# Successfully stored information for City #566: erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=erenhot
# Unfortunately, there was an error for City #567: guicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=guicheng
# Successfully stored information for City #568: pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=pisco
# Successfully stored information for City #569: soubre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=soubre
# Successfully stored information for City #570: katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=katangli
# Unfortunately, there was an error for City #571: asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=asau
# Successfully stored information for City #572: aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=aksarka
# Successfully stored information for City #573: sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sinnamary
# Successfully stored information for City #574: muhos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=muhos
# Successfully stored information for City #575: gladstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=gladstone
# Successfully stored information for City #576: gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=gat
# Successfully stored information for City #577: zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=zyryanka
# Unfortunately, there was an error for City #578: hurghada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=hurghada
# Successfully stored information for City #579: lafiagi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lafiagi
# Successfully stored information for City #580: edd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=edd
# Successfully stored information for City #581: pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=pokhara
# Unfortunately, there was an error for City #582: tarudant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tarudant
# Successfully stored information for City #583: lircay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=lircay
# Successfully stored information for City #584: belton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=belton
# Successfully stored information for City #585: takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=takoradi
# Successfully stored information for City #586: jishou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=jishou
# Successfully stored information for City #587: puerto madero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=puerto madero
# Successfully stored information for City #588: dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=dolores
# Successfully stored information for City #589: magadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=magadan
# Unfortunately, there was an error for City #590: krionerion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=krionerion
# Successfully stored information for City #591: bolitoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bolitoc
# Successfully stored information for City #592: mundo nuevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mundo nuevo
# Successfully stored information for City #593: margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=margate
# Successfully stored information for City #594: alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=alexandria
# Successfully stored information for City #595: yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=yerofey pavlovich
# Successfully stored information for City #596: gaur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=gaur
# Successfully stored information for City #597: mullingar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=mullingar
# Successfully stored information for City #598: tripoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tripoli
# Successfully stored information for City #599: sandpoint
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=sandpoint
# Successfully stored information for City #600: pinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=pinan
# Successfully stored information for City #601: cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cairns
# Successfully stored information for City #602: kyrylivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kyrylivka
# Successfully stored information for City #603: saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=saint-francois
# Successfully stored information for City #604: palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=palana
# Successfully stored information for City #605: cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=cayenne
# Successfully stored information for City #606: rancho palos verdes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=rancho palos verdes
# Unfortunately, there was an error for City #607: maykain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=maykain
# Successfully stored information for City #608: kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kulhudhuffushi
# Successfully stored information for City #609: shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=shubarshi
# Successfully stored information for City #610: clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=clyde river
# Successfully stored information for City #611: emilio carranza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=emilio carranza
# Successfully stored information for City #612: heinola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=heinola
# Successfully stored information for City #613: umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=umm lajj
# Successfully stored information for City #614: meadow lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=meadow lake
# Unfortunately, there was an error for City #615: marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=marcona
# Successfully stored information for City #616: kaspiyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kaspiyskiy
# Successfully stored information for City #617: nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=nantucket
# Unfortunately, there was an error for City #618: aban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=aban
# Successfully stored information for City #619: erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=erzin
# Successfully stored information for City #620: nampula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=nampula
# Successfully stored information for City #621: kalcheva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=kalcheva
# Successfully stored information for City #622: belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=belmonte
# Successfully stored information for City #623: tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=tiznit
# Successfully stored information for City #624: bad bevensen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e4c570add4e4bb9dd7f19f213d34b53&q=bad bevensen
# ------------------------------
# Data Retrieval Completed
# ------------------------------

# %%
# Convert the list of dictionaries Weather Data to a pandas DataFrame

weather_df = pd.DataFrame(weather_data)

# Display count to ensure that an adequate sample was obtained

weather_df.count()
# Out:
# City          562
# Clouds        562
# Country       562
# Humidity      562
# Lat           562
# Lon           562
# Max Temp      562
# Wind Speed    562
# dtype: int64

# %%
# Save the pandas DataFrame as a CSV

weather_df.to_csv("Output/Weather_Data.csv",index=False,header=True)

# Display a preview of the DataFrame

weather_df.head()
# Out:
#            City  Clouds Country  Humidity    Lat     Lon  Max Temp  Wind Speed
# 0  Quatre Cocos      40      MU        60 -20.21   57.76     71.60       16.11
# 1       Rikitea      64      PF       100 -23.12 -134.97     74.19       14.12
# 2      Kingston      20      CA        60  44.23  -76.48     78.80       12.75
# 3     Upernavik       0      GL        98  72.79  -56.15     38.64        6.06
# 4          Visp      75      CH        33  46.29    7.88     86.00       14.99

# %%
# Create scatter plot to display relationship between latitude & temperature

# Save relevant columns from the dataframe to variables
x_axis = weather_df["Lat"]
y_axis = weather_df["Max Temp"]

# Begin creating the plot

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", s=10, alpha=0.75)

# Set the x & y limits
plt.xlim(-80,100)
plt.ylim(20,130)

# Get the current time so that the date may be added to the graph title

now = datetime.now()
now = now.strftime("%m-%d-%Y")

# Create a title, and axis labels
plt.title(f"City Latitude vs. Max Temperature {now}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save the plot

plt.savefig("Output/temperature.png")

# Show the plot

plt.show()

# %%
# Create scatter plot to display relationship between latitude & humidity

# Save relevant columns from the dataframe to variables
x_axis = weather_df["Lat"]
y_axis = weather_df["Humidity"]

# Begin creating the plot

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", s=10, alpha=0.75)

# Set the x & y limits
plt.xlim(-80,100)
plt.ylim(-10,110)

# Get the current time so that the date may be added to the graph title

now = datetime.now()
now = now.strftime("%m-%d-%Y")

# Create a title, and axis labels
plt.title(f"City Latitude vs. Humidity {now}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the plot

plt.savefig("Output/humidity.png")

# Show the plot

plt.show()

# %%
# Create scatter plot to display relationship between latitude & cloudiness

# Save relevant columns from the dataframe to variables
x_axis = weather_df["Lat"]
y_axis = weather_df["Clouds"]

# Begin creating the plot

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", s=10, alpha=0.75)

# Set the x & y limits
plt.xlim(-80,100)
plt.ylim(-10,110)

# Get the current time so that the date may be added to the graph title

now = datetime.now()
now = now.strftime("%m-%d-%Y")

# Create a title, and axis labels
plt.title(f"City Latitude vs. Cloudiness {now}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the plot

plt.savefig("Output/cloudiness.png")

# Show the plot

plt.show()

# %%
# Create scatter plot to display relationship between latitude & wind speed

# Save relevant columns from the dataframe to variables
x_axis = weather_df["Lat"]
y_axis = weather_df["Wind Speed"]

# Begin creating the plot

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", s=10, alpha=0.75)

# Set the x & y limits
plt.xlim(-80,100)
plt.ylim(-5,40)

# Get the current time so that the date may be added to the graph title

now = datetime.now()
now = now.strftime("%m-%d-%Y")

# Create a title, and axis labels
plt.title(f"City Latitude vs. Wind Speed {now}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the plot

plt.savefig("Output/windspeed.png")

# Show the plot

plt.show()
